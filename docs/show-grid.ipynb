# %%
import matplotlib.pyplot as plt

import iadpython

# %config InlineBackend.figure_format = 'retina'

# %%
exp = iadpython.Experiment(default_a=0.9)
agrid = iadpython.AGrid(exp, "find_bg", tol=0.02, max_depth=6)
agrid.plot()
plt.colorbar()
plt.title("size = %d" % len(list(agrid.cache)))
plt.show()
