# %% [markdown]
# # IAD with Spheres
#
# **Scott Prahl**
#
# **March 2019**
#
# **version 1**
#
# A series of functionality tests to validate implementation of the influence of spheres on the inverse radiative transfer problem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import iadpython

# %% [markdown]
# ## Checking imports
#
# Basic sanity check to validate that module was imported

# %% [markdown]
# ## Verifying basic functionality of the objects

# %%
ss = iadpython.Sample()
print(ss)
print(ss.as_array())
# Out:
# albedo            = 0.000
# optical thickness = 1.000
# anisotropy        = 0.000
#
#   n sample          = 1.0000
#   n top slide     = 1.0000
#   n bottom slide  = 1.0000
#
# d                 = 1.000 mm
# mu_a              = 1.000 /mm
# mu_s              = 0.000 /mm
# mu_s*(1-g)        = 0.000 /mm
# Light angles
#  cos(theta incident) = 1.00000
#       theta incident = 0.0°
#  cos(theta critical) = 0.00000
#       theta critical = 90.0°
#
# [0, 1, 0, 1.0, 1]

# %%
d_sphere = 6 * 25.4
d_sample = 1 * 25.4
rs = iadpython.Sphere(d_sphere,d_sample)
ts = iadpython.Sphere(d_sphere,d_sample)

print(rs)
print(rs.as_array())
print(ts)
print(ts.as_array())
# Out:
# Sphere diameter = 152.4 mm
# Port diameters
#          sample = 25.4 mm
#        entrance = 0.0 mm
#        detector = 0.0 mm
# Diffuse reflectivities
#            wall = 1.0%
#        detector = 0.0%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-27e2ffbc8ba6> in <module>
#       5
#       6 print(rs)
# ----> 7 print(rs.as_array())
#       8 print(ts)
#       9 print(ts.as_array())
#
# AttributeError: 'Sphere' object has no attribute 'as_array'

# %%
ilum = iadpython.Illumination()
print(ilum)
print(ilum.as_array())

# %%
m = iadpython.Measurement()
print(m)
print(m.as_array())

# %%
aa = iadpython.Analysis()
print(aa)
print(aa.as_array())

# %%
e = iadpython.Experiment()
print(e)

# %% [markdown]
# ## Testing the inversion process
#
# ### First validate that changing one thing works

# %%
e = iadpython.Experiment()
a,b,g = e.invert()
print("With num_spheres = %d" % e.illumination.num_spheres)
print("    mu_s = %.3f/mm" % (a*b/e.sample.sample_thickness))
print("    mu_a = %.3f/mm" % ((1-a)*b/e.sample.sample_thickness))
print("    g    = %.4f" % g)
print()

e.illumination.num_spheres = 1
a,b,g = e.invert()
print("With num_spheres = %d" % e.illumination.num_spheres)
print("    mu_s = %.3f/mm" % (a*b/e.sample.sample_thickness))
print("    mu_a = %.3f/mm" % ((1-a)*b/e.sample.sample_thickness))
print("    g    = %.4f" % g)
print()

e.illumination.num_spheres = 2
a,b,g = e.invert()
print("With num_spheres = %d" % e.illumination.num_spheres)
print("    mu_s = %.3f/mm" % (a*b/e.sample.sample_thickness))
print("    mu_a = %.3f/mm" % ((1-a)*b/e.sample.sample_thickness))
print("    g    = %.4f" % g)
print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9cb321cdba6d> in <module>
# ----> 1 e = iadpython.Experiment()
#       2 a,b,g = e.invert()
#       3 print("With num_spheres = %d" % e.illumination.num_spheres)
#       4 print("    mu_s = %.3f/mm" % (a*b/e.sample.sample_thickness))
#       5 print("    mu_a = %.3f/mm" % ((1-a)*b/e.sample.sample_thickness))
#
# AttributeError: module 'iadpython' has no attribute 'Experiment'
